# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

import seaborn as sns

# %%
ds = pd.read_csv("data/all-cross-cycle-scores.csv", delimiter='|')

# %%
set(ds.training_cycle)
# Out:
# {'101',
#  '102',
#  '68+70+75+77+83+84+90+94+96',
#  '71',
#  '71+72+74+78+98+99+100+101+102+103+104+105+106+107+108+109',
#  '72',
#  '74',
#  '85'}

# %%
ds[(ds.training_cycle=="71+72+74+78+98+99+100+101+102+103+104+105+106+107+108+109") & (ds.image_width==128) & (ds.dense_param==64) & (ds.threshold==8000)].sort_values('acc', ascending=False)
# Out:
#      Unnamed: 0       acc  batch_size  dense_param  image_width      loss  \
# 900           0  0.999465          32           64          128  0.003108
# 906           0  0.998669          32           64          128  0.009045
# 905           0  0.996896          32           64          128  0.006659
# 899           0  0.995729          32           64          128  0.012357
# 907           0  0.992905          32           64          128  0.019556
# 935           0  0.992595          32           64          128  0.018880
# 903           0  0.990979          32           64          128  0.033808
# 898           0  0.987040          32           64          128  0.034262
# 916           0  0.986056          32           64          128  0.047507
# 902           0  0.984885          32           64          128  0.034797
# 901           0  0.984517          32           64          128  0.041819
# 936           0  0.979905          32           64          128  0.056782
# ...
